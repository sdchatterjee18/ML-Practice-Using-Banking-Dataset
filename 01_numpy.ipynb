# %%
import numpy as np
arr2=np.array([
    [1,2,3],
    [2,3,4],
    [6,7,8]
    ])
arr=np.array([1,2,3])
print("the arrray is ",arr)
print("order of the array is ",arr.shape)
print("array multiplied by 2 is ",arr*2)
print("AVARAGE oF THE ARRAY IS ",np.mean(arr))
arr1=np.array([1,'s',"souma"])
print(arr1)
print(arr2[0,1])
# Out:
# the arrray is  [1 2 3]
# order of the array is  (3,)
# array multiplied by 2 is  [2 4 6]
# AVARAGE oF THE ARRAY IS  2.0
# ['1' 's' 'souma']
# 2
